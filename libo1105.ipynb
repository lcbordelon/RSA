# %% [markdown]
# ## RSA - The Project

# %%
Name: Lindsay Bordelon 

Moodle Email: libo1105@colorado.edu

*Name your file "cuidentikey".ipynb *  This means YOUR identikey. 

*GitHub Link to Repo for Project: https://github.com/lcbordelon/RSA 


* Reminder - ALL CODE MUST BE WELL COMMENTED AND EASY TO READ - SEE MOODLE
* MUST USE A MIX OF CODE AND TEXT BLOCKS.
* A Jupyter Notebook is an interactive document - not a long scroll of code and commments.
* Do NOT delete instructions and given comments in the code. You may modify for you own use later.
* This is an important part of your course grade. All work must be well explained and well organized. Sloppy, rushed, incomplete, or otherwise demonstrating minimial effort will not recieve full credit.

# %% [markdown]
# <hr />
#
# # Table of Contents
#
# ### 1. Introduction  (5 points)
#
# ### 2. RSA Code Package    (10 points)
# ###### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.1 Basic tool set
# ###### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.2 First tool set
# ###### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.3 Second tool set
#
# ### 3. RSA More Code  (10 points)
#
# ###### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  Encode
# ###### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  Decode
#
# ### 4. Show a demo of encoding and decoding a message that highlights how your code works and the steps involved.   (20points)
#
# ### 5. Project Narrative AND results of exchanging codes with others.  (20 points)
#
# ### 6. Testing and comparing FME to mod.       (10 points)
#
# ### Points for 7 - 8 only available if the student is exchanging messages by the Friday (midnight) before the project is due.
#
# ### 7. Breaking codes without a private key    (10 points)
#
# ### 8. Advanced options (15 points) Needed to get 100%.

# %% [markdown]
# ### 1. Introduction to your RSA Package and Project.  Give an overview of your project and what you have learned.

# %% [markdown]
# Put introduction/overview here. This should be something someone who has never seen your project could read to understand what is coming.
#
# Welcome to my RSA project!
# RSA is a public key encryption method that was discovered by Rivest, Shamir, and Adleman (RSA) in 1982. RSA is also the  basis for encryption that is used over the Internet. The basis of RSA is that it is very hard to factor very large numbers. RSA makes it easy to encode and decode messages using very large numbers if the user has the public and private key.
# In this project, I'll walk you through the building blocks of RSA and how they come together to encrypt and decrypt messages. I'll also share comments on which parts of the project were difficult, which parts were a little more fun, and which aspects of RSA I would like to continue mastering.
# Overall, I learned a substantial amount from completing this project.This project pushed me to my limit and really forced me to keep pushing even when I thought I didn't know how else to solve the problems.

# %% [markdown]
# ### 2.1
# #### Basic tool set
#
# These are functions that you'll need to pre-process the messages before the messages are encoded and decoded by the RSA algorithm. That is the reason we will be defining them first.

# %%
def Convert_Text(_string):
    """
    Define this function such that it takes in a simple 
    string such as "hello" and outputs the corresponding
    standard list of integers (ascii) for each letter in the word hello.
    For example:
    _string = hello
    integer_list = [104, 101, 108, 108, 111]
    """
    integer_list = []
    for ch in _string:
        integer_list.append(ord(ch))

    return integer_list
    
_string = "Shout-The Isley Brothers"
print(Convert_Text(_string))

# %%
def Convert_Num(_list):
    """
    Do the opposite of what you did in the Convert_Text
    function defined above.
    
    Define this function such that it takes in a list of integers
    and outputs the corresponding string (ascii).
    
    For example:
    _list = [104, 101, 108, 108, 111]
    _string = hello
    """
    _string = ''
    for i in _list:
        _string += chr(i)
    return _string

_list = [80, 101, 110, 103, 117, 105, 110, 115, 32, 98, 101, 99, 97,117, 115, 101, 32, 111, 102, 32, 116, 104, 101, 105, 114, 32, 119, 97, 100, 100, 108, 101]
print("USE THIS:", Convert_Num(_list))

# %%
def Convert_Binary_String(_int):
    """
    Here, you need to define a function that converts an integer to
    a string of its binary expansion.
    
    For example:
    _int = 345
    bits = 101011001
    """
    bits = bin(_int)[2:].zfill(8)
    
    return bits

# %% [markdown]
# Now that you're done with the basic toolset we'll move on to the first tool set which is actually involved in the RSA system.

# %% [markdown]
# ### 2.2
# #### First tool set.

# %%
def FME(b, n, m):
    """
    1. Using the fast modular exponentiation algorithm,
    the below function should return b**n mod m.
    As described on page 254. (however, you may input the exponent and 
    then convert it to a string - the book verison imports the binary expansion)  
    2. You should use the function defined above
    Convert_Binary_String()
    3. Use this string to test which components are used in the calculation.
    4. Yes, there are many other ways to do this. 

***UPDATE*** You may use the function you developed in your problem set - but be sure it is your own work, commented, etc.. and change inputs as needed.
    """  

    ## A MIX OF SRIRAM'S AND MY OWN TRY
##b^n mod m..
##Define the function, pass parameters of b, n, and m
def FastModularExponentiation(b, n, m):
    #initialize the result to be 1
    res = 1
    #initialize the while loop to start when k is greater than 1. k will start at the first bit position.
    while n > 1:
        #if the least significant bit of the number is 1, not 0, move into the below code block. If the least significant bit is 0, skip it.
        if n & 1:
            #update the result variable with an assignment of the current result (1) multiplied by the current b
            # (starting at least significant bit so b = 3, 3mod645 = 3.)
            #this is only updated if the bit is 1!! If the bit wasn't 1, it would stay at res = 1
            res = (res * b) % m
        #regardless of if the bit is 1 or 0,
        # update b to be bsquared modulo m. For this first iteration it would be (3*3)mod645 = 9.
        # This is passed to the next iteration as b.
        b = b**2 % m
        #k will now be divided by 2, setting it up for the bit operation at the beginning of the
        #next iteration of the loop
        n >>= 1
    #At the very end, return the final b(111) multiplied by the final res(471) modulo m (645). =36
    return (b * res) % m


b = 2081
n = 418543
m = 2537

print(FastModularExponentiation(b, n, m))

# %%
def Euclidean_Alg(a, b):
    """
    1. Calculate the Greatest Common Divisor of a and b.
    
    2. Unless b==0, the result will have the same sign as b (so that when
    b is divided by it, the result comes out positive).
    The function must return a single integer 'x' which is
    the gcd of a and b.
    """
    #(a,b) = (n,e)
    #We run this function to verify that the gcd(n,e) = 1, which it needs to be for RSA to function correctly.
    #Initiate the while loop
    #while a is not equal to zero (terminate the loop when we get to a=0)
    while a != 0:
        #Set q as b//a. I don't need this, but I left it in to remind me of where this fits in the EEA function.
        q = b // a
        #Set k as b mod a
        k = b % a
        #At the end of each iteration, define b as a, and a as k.
        #This stores the result at the end of each iteration so that when we get to the last iteration, we store b and can use it for the gcd. This also defines b = a for the next iteration. 
        b, a = a, k
    gcd = b
    return gcd


a = 418543
b = 13

print("Euclidean_Alg:", Euclidean_Alg(a, b))

# %% [markdown]
# ### 2.3
# #### Second tool set
#
# Here we will implement the meat of the RSA cryptosystem. The functions below will generate the public and private key pairs which will then be used to create a ciphertext using the public key and then decode the same using the pirvate key.

# %%
def Find_Public_Key_e(p, q):
    """
    Implement this function such that
    it takes 2 primes p and q.
    
    Use the gcd function that you have 
    defined before.
    
    The function should return 2 elements as follows:
    public key: n
    public key: e
    
    
    HINT: this function will run a loop to find e such 
    that e is relatively prime to (p - 1) (q - 1) 
    and not equal to p or q.
    """
    #This function returns an e that is relatively prime to (p-1)*(q-1).
    #Sets n = p*q. I don't need this, but I left it in to remind me and in case I needed it further down the line. 
    n = p * q
    #Setting w to (p - 1) * (q - 1). This will make the next computation easier.
    w = (p - 1) * (q - 1)

    #Select a random integer between 1 and w.
    e = random.randint(1, w)
    #Define the variable gcd as the result of running the Euclidean_Al function with the newly computed e and w.
    gcd = Euclidean_Alg(e, w)
    #If the result (gcd) from running the Euclidean_Alg function isn't 1, then pick another random integer for e.
    while gcd != 1:
        e = random.randint(1, w)
        gcd = Euclidean_Alg(e, w)
    #If the gcd of e & w is 1, which it needs to be for RSA to function properly, then return e. 
    return e

#I input p & q after finding them from the n I selected via a 'guess & check' method. 
p = 571
q = 733

#A print statement to show me the result and to help me troubleshoot.
print("Public key progress:", Find_Public_Key_e(p, q))

# %%
def Find_Private_Key_d(m, n):
    """
    Implement this method
    to find the decryption exponent d such that
    d is the modular inverse of e. 
    
    This will use the Extended Euclidean Algorithm
    
    This function should return the following:
    d: the decryption component.
    """
    #This is the second part of the Extended_Euclidean_Alg function.
    #This functions uses two variables, m & n, and performs the EEA process to find the greatest common divisor (gcd) and the Bezout's coefficients (x,y). I nested this in another function (Find_d()) to make it easier for me to see what was being passed. 

    #Setting the bezout's coefficients to (0,1) and (1,0) to begin the EEA process. 
    x, y, u, v = 0, 1, 1, 0

    #'while m is not equal to zero' is also saying
    #'continue to run this loop all the way down until m = 0 and then stop'
    #this will also terminate the loop when n % m is 0, because m = k.
    while m != 0:

        #during each iteration define q as n divided by m (integer)
        #define k as n module m
        #the loop is keeping track of these as they change during each iteration
        q = n // m
        k = n % m

        #setting s to x-u*q and setting t to y-v*q
        s = x - u * q
        t = y - v * q

        #at the end of each loop, n,m is set as m,k; x,y is set as u,v; u,v is set as s,t
        #it does this because when the loop reached the terminating iteration (a=1), x & y need to be set as the previous u&v (s1&t1)
        #This sets x & y with the final Bezout's Coefficients
        n, m = m, k
        x, y = u, v
        u, v = s, t

    #After the last iteration, set the gcd(m,n) to n
    gcd = n
    #Return the gcd and (x,y). (x,y) are the bezout's coefficients. For encryption, d = x.
    return gcd, x, y

#This function essentially does what the Find_Private_Key_d function is asking, but I built it this way to make it easier to see what is passing into the Find_Private_Key_d function. 
def Find_d():
    #p, q, and e can be defined here or passed into the function
    p = 571
    q = 733
    e = 13

    n = p * q

    w = (p - 1) * (q - 1)

    gcd, x, y = Find_Private_Key_d(e, w)
    d = x
    #This made utilizing d easier since it's only returning one value. 
    return d


print("This is d:", Find_d())

# %%
### 3.
#### Putting things all together.

1. In this part, you will define two functions `Encode` and `Decode` which will use the public and private keys that you calculated using the above 2 functions in the second toolset.
2. Using the public key, the `Encode` function will encode a message and generate the corresponding cipher_text.
3. Using the private key, the `Decode` function will decode a ciper_text and recover the original message.

# %%
def Encode(n, e, message):
    """
    Here, the message will be a string of characters.
    Use the function Convert_Text from 
    the basic tool set and get a list of numbers.
    
    Encode each of those numbers using n and e and
    return the encoded cipher_text.
    """
    #Initializing the cipher_text list so we can use an accumulator to create the list.
    cipher_text = []
    #This print statement verifies what is being passed into the function from the Convert_Text function.
    print("This is the ASCII message to encode:", message)

    #Looping through each number from the Convert_Text list.
    for ltr in message:
        #For each letter, raise it to the power of e.
        en = (ltr**e)
        #print(en)
        #Then, calculate mod n of that number.
        C = en % n
        #print(C)
        #Append that number to the cipher_text list that will be posted to Piazza. 
        cipher_text.append(C)
#Return the completed list once the loop has ran through the list.
    return cipher_text

#Defining our variables n, e and the message to be encoded.
#When the message variable is passed into the function, it has already been converted to its ASCII numbers. 
n = 418543
e = 13
message = Convert_Text(_string)

print("SEND THIS..ENCODED MSG:", Encode(n, e, message))

# %%
def Decode(n, d, cipher_text):
    """
    Here, the cipher_text will be a list of integers.
    First, you will decrypt each of those integers using 
    n and d.
    Later, you will need to use the function Convert_Num, that converts the integers to a string, 
    from the basic toolset to recover the original message as a string. 
    
    """
        #Initialize the msg list to act as the accumulator during the loop iterations.
        msg = []

    #Create a loop that will iterate over each number in the cipher_text list
    for num in cipher_text:

        #For each number in the cipher_text list, define a new varibale M and set it to (the number raised to the power of d(private key))mod n (public key)
        M = (num**d) % n
        #append the result M to the accumulating list msg
        msg.append(M)
        
        #print(M)
        #print(msg)
    #print the final msg so I can check it with the other print statements
    print(msg)
    #return the final msg list
    return msg

#Inputted from Piazza.
n = 418543
d = 160477

cipher_text = [#copy and pasted from Piazza]

#Runs the Decode function and also converts the decoded cipher_text into it's alphabetical message using the Convert_Num function and passing the result of the Decode function. 
print("Decoded message #'s:", Convert_Num(Decode(n, d, cipher_text)))

# %% [markdown]
# ### 4.  Demonstrate how your RSA works below using a mix of text and code blocks that make it clear to the reader how this works and why you chose to put it together the way you did:
#
# * This is a step by step guide to using your code with a specific example that I can follow.
#
# * Encode a message (including generating keys).
#
# * Publish your public key and message to Piazza.
#
# * Decode messages from Piazza.
#
# * Test!
#
# Use Case #1 - Encoding A message
#
# 1. To begin, please select a large number n that is a prime number. I select n = 418543.
#
# 2. Next, select two numbers (p & q) such that n = p * q. p & q must also be relatively prime to each other (the divisor they have in common is 1). I select p=571 and q=733. To check if the two numbers are relatively prime, input the numbers as a & b into the Euclidean_Alg function and run the program. I run the program and the result in the Terminal is "Euclidean_Alg: 1"

# %%
def Euclidean_Alg(a, b):
    """
    1. Calculate the Greatest Common Divisor of a and b.
    
    2. Unless b==0, the result will have the same sign as b (so that when
    b is divided by it, the result comes out positive).
    The function must return a single integer 'x' which is
    the gcd of a and b.
    """
    while a != 0:
        q = b // a
        k = b % a
        b, a = a, k
    gcd = b
    return gcd


a = 571
b = 733

print("Euclidean_Alg:", Euclidean_Alg(a, b))

# %%
3. Now we need to find the public key, e. e is relatively prime to p & q. I can use the Find_Public_Key_e function to do this. I input p = 571 and q = 733. The terminal returns 13. Alternatively, a prime number can also be selected at random that is prime to (p-1)(q-1)

# %%
def Find_Public_Key_e(p, q):
    """
    Implement this function such that
    it takes 2 primes p and q.
    
    Use the gcd function that you have 
    defined before.
    
    The function should return 2 elements as follows:
    public key: n
    public key: e
    
    
    HINT: this function will run a loop to find e such 
    that e is relatively prime to (p - 1) (q - 1) 
    and not equal to p or q.
    """
    n = p * q
    w = (p - 1) * (q - 1)

    e = random.randint(1, w)
    gcd = Euclidean_Alg(e, w)
    while gcd != 1:
        e = random.randint(1, w)
        gcd = Euclidean_Alg(e, w)

    return e


p = 571
q = 733

print("Public key progress:", Find_Public_Key_e(p, q))

# %% [markdown]
# If you create a custom main function or a script to read codes as your CUSTOM FEATURE, you may include it here with a large heading CUSTOM FEATURE:

# %%
########CUSTOM FEATURE###################
#I struggled with converting the inputted cipher_text from a tuple to a list of integers. Per Professor Stade's advice on Piazza, I skipped it and made a basic Main function.

# %%
### 5. **Insert Narrative (ONE OR TWO pages of meaningful narrative about your process - not including the examples) here in this block. **

* Describe the results of SPECIFIC exchanging keys and codes with classmates. (at least 3 complete examples).
Example 1: Decrypting Professor Stade's initial message.
From Piazza, I inputted 5251 as n and 3403 as d into my Decode function. I also inputted the encoded message included in the Piazza post in my Decode function. Running the Decode function gave me the ASCII numerical string to use in my Convert_Num function. 
The Convert_Num function translates the numbers from their ASCII number into their alphabetical letter. This delivers the decrypted message returned in the Terminal.
encoded message (cipher_text) = [2128, 1150, 4250, 1349, 1262, 3336, 2371, 2497, 519, 1262, 1263, 1105, 3336, 1349, 1262, 2310, 1105, 3336, 4115, 762, 2405, 1263, 1105, 3336, 1262, 1349, 1150, 1105, 1262, 506, 1105, 1105, 4723, 2405, 2497, 519, 1262, 1974, 2371, 58, 1262, 519, 1105, 1349, 1262, 4839, 1150, 1105, 2497, 1262, 1974, 2371, 58, 762, 1262, 13, 4679, 1573, 1262, 4115, 2371, 2310, 1105, 1262, 2405, 3336, 1262, 4839, 2371, 762, 1560, 2405, 2497, 519, 3250]
Decoded cipher_text = [87, 104, 97, 116, 32, 115, 111, 110, 103, 32, 98, 101, 115, 116, 32, 100, 101, 115, 99, 114, 105, 98, 101, 115, 32, 116, 104, 101, 32, 102, 101, 101, 108, 105, 110, 103, 32, 121, 111, 117, 32, 103, 101, 116, 32, 119, 104, 101, 110, 32, 121, 111, 117, 114, 32, 82, 83, 65, 32, 99, 111, 100, 101, 32, 105, 115, 32, 119, 111, 114, 107, 105, 110, 103, 63]
Final message = "What song best describes the feeling you get when your RSA code is working?"
To reply to Professor Stade's message, I left n and d as is, but I inputted 3 for e for the Encode function. I inputted the message I wanted to reply with in the variable _string. The _string variable is used in the Conver_Text function. The Convert_Text function converts a list of letters and translates them into their corresponding ASCII number. Running the Convert_Text function gave me the list of ASCII numbers that is then fed into my Encode function via the message variable. Running the Encode function output the cipher_text that I finally posted in Piazza as a reply to Professor Stade's original question. Voila!
_string = "Shout-The Isley Brothers"
message = [83, 104, 111, 117, 116, 45, 84, 104, 101, 32, 73, 115, 108, 101, 121, 32, 66, 114, 111, 116, 104, 101, 114, 115]
encoded message(cipher_text): [4679, 1150, 2371, 58, 1349, 1858, 4592, 1150, 1105, 1262, 443, 3336, 4723, 1105, 1974, 1262, 3942, 762, 2371, 1349, 1150, 1105, 762, 3336]

Example 2: Decrypting Jill Kollar's message.
From Piazza, I inputted 2537 as n and 937 as d into my Decode function. I also inputted the encoded message included in the Piazza post in my Decode function. Running the Decode function gave me the ASCII numerical string to use in my Convert_Num function. 
The Convert_Num function translates the numbers from their ASCII number into their alphabetical letter. This delivers the decrypted message returned in the Terminal.
encoded message (cipher_text) = [560, 803, 1736, 1544, 197, 794, 197, 1544, 1736, 1648, 943, 1544, 197, 1342, 533, 794, 197, 1342, 1544, 2133, 1648, 1544, 197, 1648, 1544, 2133, 803, 794, 2512, 1544, 933, 1648, 2512, 2133, 1, 1508, 1552, 533, 533, 1544, 933, 1453, 1648, 185, 1453, 1552, 24, 1438]
Decoded cipher_text = [87, 104, 121, 32, 100, 105, 100, 32, 121, 111, 117, 32, 100, 101, 99, 105, 100, 101, 32, 116, 111, 32, 100, 111, 32, 116, 104, 105, 115, 32, 112, 111, 115, 116, 1, 98, 97, 99, 99, 32, 112, 114, 111, 103, 114, 97, 109, 63]
Final message = "Why did you decide to do this post☺bacc program?"
To reply to Jill's message, I left n and d as is, but I inputted 13 for e for the Encode function. I inputted the message I wanted to reply with in the variable _string. The _string variable is used in the Conver_Text function. The Convert_Text function converts a list of letters and translates them into their corresponding ASCII number. Running the Convert_Text function gave me the list of ASCII numbers that is then fed into my Encode function via the message variable. Running the Encode function output the cipher_text that I finally posted in Piazza as a reply to Jill's original question. 
_string = "to learn more about computers and coding"
message = [83, 104, 111, 117, 116, 45, 84, 104, 101, 32, 73, 115, 108, 101, 121, 32, 66, 114, 111, 116, 104, 101, 114, 115]
encoded message(cipher_text): [2133, 1648, 1544, 1550, 1342, 1552, 1453, 1614, 1544, 24, 1648, 1453, 1342, 1544, 1552, 1508, 1648, 943, 2133, 1544, 533, 1648, 24, 933, 943, 2133, 1342, 1453, 2512, 1544, 1552, 1614, 197, 1544, 533, 1648, 197, 794, 1614, 185]




Example 3:Decrypting Matt Fournier's response to my Piazza message (narrative for that post above).
From Piazza, I inputted 418543 as n and 160477 as d into my Decode function. I also inputted the encoded message included in the Piazza post in my Decode function. Running the Decode function gave me the ASCII numerical string to use in my Convert_Num function. 
The Convert_Num function translates the numbers from their ASCII number into their alphabetical letter. This delivers the decrypted message returned in the Terminal.
encoded message (cipher_text) = [101159, 182599, 152567, 135396, 129591, 107955, 152567, 242273, 25439, 209302, 182599, 56560, 3904, 129591, 242273, 182599, 25439, 355570, 120553, 25439, 291951, 377459, 182599, 107955, 209063, 25439, 51289, 3904, 50208, 50208, 229476, 182599]
Decoded cipher_text = [80, 101, 110, 103, 117, 105, 110, 115, 32, 98, 101, 99, 97, 117, 115, 101, 32, 111, 102, 32, 116, 104, 101, 105, 114, 32, 119, 97, 100, 100, 108, 101]
Final message = "Penguins because of their waddle"






* What was challenging? 
This entire project was challenging for me. Although I have experience coding with full stack languages, coding with this level of math was outside of my comfort zone. The hardest part was how time consuming it was for me to FULLY understand the big functions (FME, EEA, Factoring). I'm happy that I took the time to understand what each function does, but it took away time that I could've spend doing more advanced functions. 

I also struggled with the advanced portion of the code. I tried to create a Main function. As a novice Python coder, this was frustrating in that it felt like I wasn't adding real value to the project. However, every moment I spent on this project has given me more confiden in my coding skills. It wasn't always pretty, but I definitely feel like I moved to a higher level of developer from when I started this project (woo!). 

* Who helped you with your project? 
Piazza, Kristen, and the Python documentation. 
https://docs.python.org/3/ 

* Which resources were most helpful?
The most helpful resources for me were Python documentation (troubleshooting why my functions weren't working), people's discussions on Piazza, and my past Mastery Workbooks. I also talked through some of the bigger functions during office hours. Talking through the functions was probably the most impactful thing I did during the entire project. It really forced me to articulate what I thought the function was doing, even if I was lost. 
Most of my errors during coding came from not understanding how Python operates pieces of the code. I had to spend a lot of time in the Python documentation to understand where my errors were coming from. It was also tremendously helpful for me to use print statements to see where my errors were coming from. I've left most of them in my code, commented out, to show my thought process while coding. 
It also helped that I tried to attack one function each day during the RSA project week. It made the entire project seem less intimidating and let me focus on the function at hand, instead of freaking out about the entire project.

* What was your Best Mistake, (funniest? most frustrating? the one you learned the most from?)
#Best/biggest mistake (can probably still see remnants of it...) was having my functions separated to the point where I had to copy/paste the encoded message and decoded message into their specific parts in the code for the functions to run properly. This was mostly amateur python mistakes, but definitely something that I learned from. Although it was a 'mistake', it significantly helped me in writing code from algorithms. It forced me to think about which step each function needed to accomplish and the steps required within each function. I was proud of myself for how much of the code I got right on the first try. 
#Another mistake that may not be a mistake is with the brute force factoring. When I tried to code break a large n, it took my computer hours to process it before I eventually terminated the process. I wish I could've spent more time on advanced factoring and Pollard's Rho, but I simply ran out of time. 
#The most frustrating mistake was trying to create the Main function, but not being able to get past converting the inputted cipher_text from a tuple to a list of integers. This was maddening as I had a good plan for creating the Main function (noted with Main function). Tuples were skimmed over in 1300, but I wish it would've been covered if we're expected to know how to do it in this class. Because of the disconnect between what we're focusing on in 1300 and what was required for the advanced portion of the project, the advanced portion should be extra credit and not automatically dock those of us that are new to Python. 

* Again, be sure to include results and a discussion of specific exchanges with others.

# %%
### 6. FME Exploration - (CODE INTERVIEW type question)



* Explain in detail (give an example) why RSA needs to use an FME function and cannot just simply use the Python Mod function % .

RSA needs to use Fast Modular Exponentiation (FME) instead of the Python Mod function(%) because of the size of integers that are involved in RSA. The Python Mod function % functions well until the base exceeds nine digits and the power exceeds seven digits. The reasoning behind this is that with the Python Mod function %, the function is attempting to process the modular arithmetic all at once and this takes a very long time (much like how it would take my brain forever to calculate the answer). In contrast, FME is using binary conversion to only calculate the mod for numbers that are factors of the number. This drastically reduces the amount of processing the function has to do and decreases the size of integers the function has to process. See notes in code for more information. 

For example, if I run the Python Mod function % for (1568160359)^20000446 mod 645, my computer will process for hours. The process will take so long that I'll end up terminating the process and moving on to using FME. However, if I use FME for the same equation, I receive the answer (31) in about two seconds. 

* You may use your arguments from the Number theory Mastery Workbook.

* You may wish to use an example from code breaking.
# Out:
# Error: IPyKernel not installed into interpreter Python 3.9.5 64-bit:C:\Python39\python.exe
# at w.handleKernelDependencyResponse (c:\Users\lcbor\.vscode\extensions\ms-toolsai.jupyter-2021.6.999662501\out\client\extension.js:90:244702)
# at w.installMissingDependencies (c:\Users\lcbor\.vscode\extensions\ms-toolsai.jupyter-2021.6.999662501\out\client\extension.js:90:244075)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)

# %% [markdown]
# ## CODE BREAKING ##
#
# This section of the project is only available to students exchanging codes by the Friday (midnight) before the project is due.
#
# After you have tested your RSA package yourself, and tested it with classmates by publishing both the private and public keys on Piazza, post 2 messages with just the public keys for people to break on the "Just Public Keys" thread - use both very small n ‘s (under 1000) for practice, and some with a challenge.
#
#
# **Implementing a factoring algorithm:**
#
# Begin by coding the basic brute force factorization algorithm given in pseudocode below.
#
# Brute Force Factoring
# <pre><code>def factorize(n):
#     # n is a number, return the smallest factor of n
#     for i from 2 to n-1:
#         if i divides n:
#             return i
#         return FALSE
#         </code></pre>

# %% [markdown]
# ### 7. Do the following for full credit in number 7
# * To break others’ code you just need to factor n (public key). **Explain how and why code breaking works in a text block.**
#
# * Demonstrate 1 example of breaking a code with a small n, and show the steps involved.
#
# * Now attempt codes with larger n
#
# * Describe your attempt to break codes with large n. At what values would you say n's get difficult? (too large to factor)
#
# * Show COMPLETELY at least 3 codes you broke and/or codes of your that were broken.

# %%
#####CODE BREAKING####################
##The basis of code breaking is that we're trying to find the smallest factor of n that can be used as p. 
##We want p to be a smaller factor of n, but can be any factor that can be multiplied by a factor q to give us n = p * q. 
##We need p & q as guidance for what we select for e. e, p & q are needed for the Find_Private_key_d function, that uses the
##Extended Euclidean Algorithm to find d. 
##Once I have d, I can use the Decode function to decode the cipher text. 


def factorize(n):
    #for every number in the range of (between) 2 and n-1...
    for i in range(2, n - 1):
        #if n mod the number equals zero AND the number mod 2 does not equal zero (not divisible by 2) AND the number mod 5 does not equal zero (not divisible by 5)...
        if n % i == 0 and i % 2 != 0 and i % 5 != 0:
            #then select and print and return that number
            #this number is p
            print(i)
            return i


n = 130177

print("this is p:", factorize(n))

#Setting p to the result of the factorize function
p = factorize(n)
#Setting q equal to n dividied by p so that n = p * q
q = n // p
print("this is q:", q)

#Utilizing the Find_d function from above to return d while using the factorize function.
#I ran the factorize function twice so I could see what p and d are being returned as. 
def Find_d(p, q, e):

    w = (p - 1) * (q - 1)

    gcd, x, y = Find_Private_Key_d(e, w)
    d = x

    return d

#Setting p to the result of the factorize function
p = factorize(n)
#Setting q equal to n dividied by p so that n = p * q
q = n // p
#Inputting e from Piazza.
e = 13

print("This is d:", Find_d(p, q, e))

####Code Breaking examples
##Examples below use portions of the code, not the entire Main() function. I worked on the Main() function at the end of all the other processes.
#Example 1:  n = 130177; e = 13. This is a relatively small n.
#I insert 130177 for n and 13 for e in the code block above and then run the factorize and main function.
#It returns p = 349, q = 373, d = 59749.
#I input 59749 as d for the Decode function. I input the cipher text and run the Decode function.
#The Decode function returns the list of integers that I input into the Convert_Num function
#Running the Convert_Num function gives me the final message. 
#Decoded Message: [84, 104, 101, 32, 98, 101, 115, 116, 32, 116, 104, 105, 110, 103, 32, 97, 98, 111, 117, 116, 32, 97, 32, 66, 111, 111, 108, 101, 97, 110, 32, 105, 115, 32, 101, 118, 101, 110, 32, 105, 102, 32, 121, 111, 117, 32, 97, 114, 101, 32, 119, 114, 111, 110, 103, 44, 32, 121, 111, 117, 32, 97, 114, 101, 32, 111, 110, 108, 121, 32, 111, 102, 102, 32, 98, 121, 32, 97, 32, 98, 105, 116, 46]
#Final Message: "The best thing about a Boolean is even if you are wrong, you are only off by a bit."

#Example 2: n = 28794290241716387; e = 113. Bigger n.
#I insert 28794290241716387 for n and 113 for e in the code block above and then run the factorize and main function.
#It returns p = 160481219, q = 179424673, d = 5096334495895663
#This took MUCH longer than the previous example (I walked away from my computer). 
#It also returned a negative d on the first run. I then added abs() to the d and it returned a positive d.
#I input 59749 as d for the Decode function. I input the cipher text and run the Decode function.
#The Decode function returns the list of integers that I input into the Convert_Num function
#This also took much longer than the previous example. It took hours and I eventually terminated the process. I think above eight digits is when the process starts to really slow down. I didn't have time to work on more advanced factoring, but I think working on that and implementing a factoring function utilizing a variation of the Extended Euclidean Algorithm might have helped. 
#Running the Convert_Num function gives me the final message. I also at the time still had the print functions in the Decode loop.  I'm sure that didn't help the speed of the process. 
#Decoded Message: N/A, process ran too long
#Final Message: N/A, process ran too long

#Example 3: n = 2929; e = 59. 
#I insert 2929 for n and 59 for e in the code block above and then run the factorize and main function.
#It returns p = 29, q = 101, d = 1139
#This took barely a second because n is smaller.
#I input 1139 as d for the Decode function. I input the cipher text and run the Decode function.
#The Decode function returns the list of integers that I input into the Convert_Num function
#Running the Convert_Num function gives me the final message. 
#Decoded Message: [57, 57, 32, 108, 105, 116, 116, 108, 101, 32, 98, 117, 103, 115, 32, 105, 110, 32, 116, 104, 101, 32, 99, 111, 100, 101, 46, 32, 57, 57, 32, 108, 105, 116, 116, 108, 101, 32, 98, 117, 103, 115, 32, 105, 110, 32, 116, 104, 101, 32, 99, 111, 100, 101, 46, 32, 84, 97, 107, 101, 32, 111, 110, 101, 32, 100, 111, 119, 110, 44, 32, 112, 97, 115, 115, 32, 105, 116, 32, 97, 114, 111, 117, 110, 100, 46, 32, 49, 50, 55, 32, 108, 105, 116, 116, 108, 101, 32, 98, 117, 103, 115, 32, 105, 110, 32, 
116, 104, 101, 32, 99, 111, 100, 101, 46, 46, 46]
#Final Message: "99 little bugs in the code. 99 little bugs in the code. Take one down, pass it around. 127 little bugs in the code..." This one made me laugh, thanks Ben!

# %% [markdown]
# ## Custom Feature ##
# The last 15 points of the require a custom feature in your project. This is an opportinity for you to explore an RSA or coding topic of interest to you. At this point it is not about points, but exploring advanced ideas relevant to you.  This is also a feature that should be relevant to your programming ability. If you are in 1300, creating a main type function may be enough. If you are an experienced programmer, find a topic to push yourself.
#
#
# Custom Features could one or more of the following:
#
# 1. A Python "main" function that allows a user to "Get keys/Encode/Decode/Break Codes" etc...
# 2. An exploration of factoring improvements and analyze how effective they are. Must include some kind of timing analysis and multiple code breaking. A superficial treatment will not recieve full points. Must be throughly tested with excellent investigations to recieve full points.
# 3. A script to read codes from Piazza data. You can copy and paste codes from Piazza into a txt files and then have your script read it. This is a VERY helpful tool for doing the project as well.
# 4. Exploration of advanced factoring alogrithms (see Moodle) Try Pollard's Rho <- super satisfying. (full points if well - impemented with thoughtful examples)
# 5. Advanced complexity analysis.
# 6. Other options available, please ask.
#
# The Custom Feature is an important part of the project, and it should be a non-trivial response.
# Please help organize your Custom Feature by breaking it up into sections - ie. not one long block of text.
# Mininimally executed, "dialling it in" type features will not recieve full points.
# See below for more detials on grading of this section.

# %% [markdown]
# **Please use the grading guide below to self grade your Custom Feature.**
#
# GRADING FOR CUSTOM FEATURE:
#
# 15 pts  Wow.  It is amazing.
#         Shows initiative and originality.
#         You did something extra special and pushed yourself.
#         You went beyond all expectations
#         You broke the rules in a creative way.
#         Your coding and commenting is exceptional.
#         Excellent
#
# 10 - 14 points - It is GOOD!
#         You were a “self starter”.
#          You did everything  requested.
#         All expectations met.
#        	You did a very good job.
#         Good use of commenting.
#         Shows mastery of skills.
#
# 5 -10 points  - Okay.
#         Minimum requirements.
#         Commenting weak.
#
# 0 -5 points - It is not finished.
#           Does meet objectives.
#             Did not follow directions.
#             Choose not to do this part (which is a totally fine choice)

# %% [markdown]
# ## Self grading of custom feature ##
#
# Here in this block
#
# Please rate what score out of 15 your custom feature merits given the criteria above:
#
# * For example, if you are brand new to programming, using a main function could be an amazing feature - tell me how this helped you move to a new level.
# * In what ways did YOU push yourself? Did you try something you've never done before?
# * Alternatively, if you just did not have the time to do the custum feature, that is actually just fine and a reasonable choice for an adult. No judgment.
#
# Custom Feature (organized Main function for each process) = 7 points
# I attempted to create a Main function, but was stuck on the process of converting a tuple into a string for several hours. Since tuple conversion wasn't fully covered in 1300, I don't think I should be docked points for not being able to provide a full Main function custom feature. We weren't required to have advanced Python knowledge coming into this class, thus I don't think I should be punished via having points removed from my project because of that. My main function attempt is included above, even though it isn't functional yet.

# %% [markdown]
# ## Grading Notes ##
#
# *The project will consist of a combination of text and code blocks.
#
# *Grading - all code must be well commented. These should be easy to read. Here is a simple guide: https://realpython.com/python-comments-guide/
#
# *See notes in Moodle about comments a
#
# *The narrative elements of the project are just as important as the coding.
#
# *Do NOT copy code from the internet (or anywhere)
#
# *Do not ask questions on stackoverflow or similar etc…
#
# *You are expected to have read the honesty notes in the syllabus.
#
# *Credit sources you used for additional understanding.
#
# *Credit classmates that helped you.
